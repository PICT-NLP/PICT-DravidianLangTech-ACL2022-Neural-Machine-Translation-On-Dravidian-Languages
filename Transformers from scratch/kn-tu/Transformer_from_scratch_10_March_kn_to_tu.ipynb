# %%
# %%capture
 # w and b (wandb) for logging
! pip install wandb

# sacremos - for tokenizing
! pip install sacremos

# fairseq - for training and evaluation of the model
! git clone https://github.com/pytorch/fairseq
# %cd fairseq
! pip install --editable ./
# %cd ..

# %cd /content/fairseq/
# !python -m pip install --editable .
# %cd /content

! echo $PYTHONPATH

import os
os.environ['PYTHONPATH'] += ":/content/fairseq/"

! echo $PYTHONPATH

# %%
import wandb
wandb.login()
# login authorization.
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !unzip /content/tokenized_kn_tu.zip
# Out:
# Archive:  /content/tokenized_kn_tu.zip
#    creating: content/nmt-kn-tu/tokenized.kn-tu/
#   inflating: content/nmt-kn-tu/tokenized.kn-tu/test.kn-tu.tu.bin
#   inflating: content/nmt-kn-tu/tokenized.kn-tu/test.kn-tu.kn.bin
#   inflating: content/nmt-kn-tu/tokenized.kn-tu/test.kn-tu.kn.idx
#   inflating: content/nmt-kn-tu/tokenized.kn-tu/valid.kn-tu.kn.bin
#   inflating: content/nmt-kn-tu/tokenized.kn-tu/train.kn-tu.kn.bin
#   inflating: content/nmt-kn-tu/tokenized.kn-tu/valid.kn-tu.tu.bin
#   inflating: content/nmt-kn-tu/tokenized.kn-tu/preprocess.log
#   inflating: content/nmt-kn-tu/tokenized.kn-tu/test.kn-tu.tu.idx
#   inflating: content/nmt-kn-tu/tokenized.kn-tu/train.kn-tu.kn.idx
#   inflating: content/nmt-kn-tu/tokenized.kn-tu/valid.kn-tu.kn.idx
#   inflating: content/nmt-kn-tu/tokenized.kn-tu/valid.kn-tu.tu.idx
#   inflating: content/nmt-kn-tu/tokenized.kn-tu/dict.tu.txt
#   inflating: content/nmt-kn-tu/tokenized.kn-tu/train.kn-tu.tu.idx
# ...

# %%
! fairseq-train /content/content/nmt-kn-tu/tokenized.kn-tu \
--arch transformer \
--dropout 0.1 \
--attention-dropout 0.1 \
--activation-dropout 0.1 \
--encoder-embed-dim 256 \
--encoder-ffn-embed-dim 512 \
--encoder-layers 3 \
--encoder-attention-heads 8 \
--encoder-learned-pos \
--decoder-ffn-embed-dim 512 \
--decoder-layers 3 \
--decoder-attention-heads 8 \
--decoder-learned-pos \
--max-epoch 10 \
--optimizer adam \
--lr 5e-4 \
--batch-size 128 \
--seed 1 \
--wandb-project "Transformer from scratch - 10 March - kn to tu"
# Out:
# 2022-03-10 06:22:02 | INFO | numexpr.utils | NumExpr defaulting to 2 threads.
# 2022-03-10 06:22:04 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# ...

# %%
# !fairseq-generate /content/content/nmt-kn-tu/tokenized.kn-tu \
  --path /content/checkpoints/checkpoint_best.pt \
  --beam 5 \
  --remove-bpe \
 | grep ^H | LC_ALL=C sort -V | cut -f3- > test_tu_generated_scratch_transformer.txt
# Out:
# 2022-03-10 06:24:23 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# ...

# %%
# !fairseq-generate /content/content/nmt-kn-tu/tokenized.kn-tu \
  --path /content/checkpoints/checkpoint_best.pt \
  --beam 5 \
   --remove-bpe \
  | grep ^T | LC_ALL=C sort -V | cut -f2- > test_tu_actual_scratch_transformer.txt
# Out:
# 2022-03-10 06:25:02 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# ...

# %%
# !fairseq-score --sys /content/test_tu_generated_scratch_transformer.txt --ref /content/test_tu_actual_scratch_transformer.txt
# Out:
# 2022-03-10 06:25:44 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# Namespace(ignore_case=False, order=4, ref='/content/test_tu_actual_scratch_transformer.txt', sacrebleu=False, sentence_bleu=False, sys='/content/test_tu_generated_scratch_transformer.txt')
# BLEU4 = 21.02, 44.1/23.7/16.3/11.5 (BP=1.000, ratio=1.049, syslen=14926, reflen=14228)

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu
f = open("/content/test_tu_generated_scratch_transformer.txt")
ml_candidates = [i.strip() for i in f.readlines()]
f = open("/content/test_tu_actual_scratch_transformer.txt")
ml_gold = [i.strip() for i in f.readlines()]
total_four = 0
for i in range(len(ml_candidates)):
    candidate = ml_candidates[i].split(" ")
    references = ml_gold[i].split(" ")
    reference = [references]
    score_cumulative4 = sentence_bleu(reference, candidate, weights=(0.25, 0.25, 0.25, 0.25))
    total_four = total_four + score_cumulative4
print(total_four/len(ml_candidates))
# Out:
# 0.5551370707092514
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
